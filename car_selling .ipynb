# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\M\Downloads\archive (6)\car data.csv")

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %%
print(df['Transmission'].unique())
print(df['Seller_Type'].unique())
print(df['Owner'].unique())
print(df['Fuel_Type'].unique())
# Out:
# ['Manual' 'Automatic']
# ['Dealer' 'Individual']
# [0 1 3]
# ['Petrol' 'Diesel' 'CNG']

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
final_dataset=df[["Year","Selling_Price","Present_Price","Kms_Driven","Fuel_Type","Seller_Type","Transmission","Owner"]]

# %%
final_dataset
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# ...

# %%
final_dataset=df.drop(['Car_Name'],axis=1)

# %%
final_dataset
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# ...

# %%
import time
final_dataset['current_year']=2023

# %%
final_dataset
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  current_year
# 0         Manual      0          2023
# ...

# %%
final_dataset['num_year']=final_dataset['current_year']-final_dataset['Year']

# %%
final_dataset.drop(['current_year','Year'],axis=1,inplace=True)

# %%
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  num_year
# 0       Manual      0         9
# 1       Manual      0        10
# 2       Manual      0         6
# 3       Manual      0        12
# 4       Manual      0         9

# %%
# final_dataset=pd.get_dummies(final_dataset,drop_first=True)
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
final_dataset['Fuel_Type'] = label_encoder.fit_transform(final_dataset['Fuel_Type'])
final_dataset['Seller_Type'] = label_encoder.fit_transform(final_dataset['Seller_Type'])
final_dataset['Transmission'] = label_encoder.fit_transform(final_dataset['Transmission'])

# %%
print("Fuel_Type:", final_dataset['Fuel_Type'].unique())
final_dataset
# Out:
# Fuel_Type: [2 1 0]
#      Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0             3.35           5.59       27000          2            0
# 1             4.75           9.54       43000          1            0
# 2             7.25           9.85        6900          2            0
# 3             2.85           4.15        5200          2            0
# 4             4.60           6.87       42450          1            0
# ..             ...            ...         ...        ...          ...
# 296           9.50          11.60       33988          1            0
# 297           4.00           5.90       60000          2            0
# 298           3.35          11.00       87934          2            0
# 299          11.50          12.50        9000          1            0
# 300           5.30           5.90        5464          2            0
#
#      Transmission  Owner  num_year
# 0               1      0         9
# ...

# %%
final_dataset.corr()
# Out:
#                Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# Selling_Price       1.000000       0.878983    0.029187  -0.509467
# Present_Price       0.878983       1.000000    0.203647  -0.440415
# Kms_Driven          0.029187       0.203647    1.000000  -0.166801
# Fuel_Type          -0.509467      -0.440415   -0.166801   1.000000
# Seller_Type        -0.550724      -0.512030   -0.101419   0.352415
# Transmission       -0.367128      -0.348715   -0.162510   0.080466
# Owner              -0.088344       0.008057    0.089216   0.055705
# num_year           -0.236141       0.047584    0.524342   0.053643
#
#                Seller_Type  Transmission     Owner  num_year
# Selling_Price    -0.550724     -0.367128 -0.088344 -0.236141
# Present_Price    -0.512030     -0.348715  0.008057  0.047584
# Kms_Driven       -0.101419     -0.162510  0.089216  0.524342
# Fuel_Type         0.352415      0.080466  0.055705  0.053643
# ...

# %%
import seaborn as sns
import matplotlib as plt

# %%
sns.pairplot(final_dataset)

# %%
cormat=final_dataset.corr()
top_corr_feature=cormat.index
#plt.figure(figsize=(20,20))
sns.heatmap(final_dataset[top_corr_feature].corr(), annot=True)
# Out:
# <Axes: >

# %%
final_dataset
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0             3.35           5.59       27000          2            0
# 1             4.75           9.54       43000          1            0
# 2             7.25           9.85        6900          2            0
# 3             2.85           4.15        5200          2            0
# 4             4.60           6.87       42450          1            0
# ..             ...            ...         ...        ...          ...
# 296           9.50          11.60       33988          1            0
# 297           4.00           5.90       60000          2            0
# 298           3.35          11.00       87934          2            0
# 299          11.50          12.50        9000          1            0
# 300           5.30           5.90        5464          2            0
#
#      Transmission  Owner  num_year
# 0               1      0         9
# 1               1      0        10
# ...

# %%
x=final_dataset.iloc[:,1:]
y=final_dataset.iloc[:,0]

# %%
print(x)
# Out:
#      Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner  \
# 0             5.59       27000          2            0             1      0
# 1             9.54       43000          1            0             1      0
# 2             9.85        6900          2            0             1      0
# 3             4.15        5200          2            0             1      0
# 4             6.87       42450          1            0             1      0
# ..             ...         ...        ...          ...           ...    ...
# 296          11.60       33988          1            0             1      0
# 297           5.90       60000          2            0             1      0
# 298          11.00       87934          2            0             1      0
# 299          12.50        9000          1            0             1      0
# 300           5.90        5464          2            0             1      0
#
#      num_year
# 0           9
# 1          10
# ...

# %%
x.head()
# Out:
#    Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner  \
# 0           5.59       27000          2            0             1      0
# 1           9.54       43000          1            0             1      0
# 2           9.85        6900          2            0             1      0
# 3           4.15        5200          2            0             1      0
# 4           6.87       42450          1            0             1      0
#
#    num_year
# 0         9
# 1        10
# 2         6
# 3        12
# 4         9

# %%
y.head()
# Out:
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# 4    4.60
# Name: Selling_Price, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()

# %%
scalar.fit_transform(X_train,y_train)
# Out:
# array([[-0.76923237, -0.83904661,  0.48756643, ..., -2.85139173,
#         -0.18730358,  1.99046855],
#        [ 1.26268234,  0.43381798,  0.48756643, ...,  0.35070593,
#         -0.18730358,  0.24444351],
#        [ 0.38139709,  0.12793616, -1.83945516, ...,  0.35070593,
#         -0.18730358, -0.80317152],
#        ...,
#        [-0.44579392, -0.49554421,  0.48756643, ...,  0.35070593,
#          3.38849211, -0.1047615 ],
#        [ 0.292367  ,  0.74767564,  0.48756643, ...,  0.35070593,
#         -0.18730358,  0.94285352],
#        [-0.63399678, -0.78963873,  0.48756643, ...,  0.35070593,
#         -0.18730358, -1.15237653]])

# %%
import pickle
pickle.dump(scalar,open('scaling.pkl','wb'))

# %%
X_train
# Out:
# array([[-0.76923237, -0.83904661,  0.48756643, ..., -2.85139173,
#         -0.18730358,  1.99046855],
#        [ 1.26268234,  0.43381798,  0.48756643, ...,  0.35070593,
#         -0.18730358,  0.24444351],
#        [ 0.38139709,  0.12793616, -1.83945516, ...,  0.35070593,
#         -0.18730358, -0.80317152],
#        ...,
#        [-0.44579392, -0.49554421,  0.48756643, ...,  0.35070593,
#          3.38849211, -0.1047615 ],
#        [ 0.292367  ,  0.74767564,  0.48756643, ...,  0.35070593,
#         -0.18730358,  0.94285352],
#        [-0.63399678, -0.78963873,  0.48756643, ...,  0.35070593,
#         -0.18730358, -1.15237653]])

# %%
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression()
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(regression.coef_)
# Out:
# [ 3.80722631 -0.16082884 -0.62197465 -0.54035334 -0.45025512 -0.29294644
#  -1.05890918]

# %%
reg_pred=regression.predict(X_test)
reg_pred
# Out:
# array([ 2.84503948,  8.17433042,  6.15503229, -1.53474297,  9.10478102,
#         7.12513416,  1.41208877,  0.85727713,  1.42824591,  7.18732696,
#         8.77738476,  0.64604862,  8.19199294,  3.27496701,  6.58156734,
#         3.12524913,  0.47776322, 10.71519858,  1.81845542,  2.3948969 ,
#         0.40800604,  7.78763597,  6.25976337,  2.59710749,  0.8401473 ,
#         3.68243396,  5.30447357,  2.81900104,  2.20840021,  1.82500826,
#         0.41732684,  8.85691122, -0.6636885 ,  2.2707602 ,  8.2948583 ,
#         4.51208942,  7.29749227,  7.54243321,  2.9482584 ,  7.9275823 ,
#         3.90745022,  4.17258578,  4.31519575,  0.69858995,  7.02594603,
#         0.53398622,  7.32449179, 11.09649499,  3.13148761,  5.06495644,
#         6.60928574,  2.2345092 , 20.15115757, 16.47662698,  7.25913588,
#         9.54127202,  4.43952683,  8.67649783,  1.75283042,  7.41244863,
#         0.27553659, -2.53278607,  2.01366813, -1.56020807,  4.79226982,
# ...

# %%
## scatter plot for the predictor
import matplotlib.pyplot as plt
plt.scatter(reg_pred,y_test)

# %%
## residual error
residuals=y_test-reg_pred
residuals
# Out:
# 177   -2.495039
# 289    1.935670
# 228   -1.205032
# 198    1.684743
# 60    -2.154781
#          ...
# 119    0.115019
# 19    -0.779087
# 181   -0.966282
# 79    -2.087431
# 114   -0.296144
# Name: Selling_Price, Length: 91, dtype: float64

# %%
## plot this residual

sns.displot(residuals,kind='kde')

# %%
## scatter plot with respect to prediction and residiuals
plt.scatter(reg_pred,residuals)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
print(mean_squared_error(y_test,reg_pred))
print(mean_absolute_error(y_test,reg_pred))
print(np.sqrt(mean_squared_error(y_test,reg_pred)))
# Out:
# 3.4932860262251455
# 1.2581404706473371
# 1.8690334470589727

# %%
## R square and adjusted R square
from sklearn.metrics import r2_score
score=r2_score(y_test,reg_pred)
score
# Out:
# 0.8773175030338536

# %%
## pickling the model file for deployment
import pickle

# %%
pickle.dump(regression,open(r'regmodel.pkl','wb'))

# %%
pickled_model=pickle.load(open(r'C:\Users\M\Downloads\archive (6)\car data.pkl','rb'))
pickled_model
# Out:
# LinearRegression()

# %%
##Prediction
pickled_model.predict(pd.DataFrame([[3994,27090,1,8,1,0,1,0]],columns=['Present_Price','Kms_Driven','Owner','num_year','Fuel_Type_Diesel','Fuel_Type_Petrol','Seller_Type_Individual','Transmission_Manual']))
# Out:
# c:\Users\M\anaconda3\Lib\site-packages\sklearn\base.py:457: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# array([9666.37964685])
